# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.model_selection import (
    cross_val_score,
    cross_validate,
    train_test_split,
)
from sklearn.linear_model import LinearRegression
from datetime import datetime, timedelta

from scipy.stats import norm
from statsmodels.tsa.statespace.sarimax import SARIMAX

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
import pmdarima as pm

import matplotlib.pyplot as plt

from skforecast.ForecasterAutoreg import ForecasterAutoreg
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

from pmdarima import auto_arima

# %%
df= pd.read_csv("data/jenny/new_df2.csv")
df["date"] = pd.to_datetime(df["date"], format='%Y-%m-%d')
df = df.set_index("date")
# df = df.sort_index()
# df = df.asfreq('MS')
# df.index = pd.to_datetime(df.index)
print(df.dtypes)
df.head(3)
# Out:
# month                   int64
# year                    int64
# Temp                  float64
# Flow                  float64
# Level                 float64
# count                 float64
# october_Flow          float64
# november_Flow         float64
# december_Temp         float64
# january_Temp          float64
# feburary_Temp         float64
# october_Level         float64
# november_Level        float64
# rolling_mean_Temp     float64
# rolling_std_Temp      float64
# rolling_mean_Flow     float64
# rolling_std_Flow      float64
# rolling_mean_Level    float64
# rolling_std_Level     float64
# dtype: object
#             month  year       Temp    Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273  0.8755  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833  0.7905  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500  0.7490  0.5365    0.0      7.679129
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2013-09-02        28.3825       3.965188      4.324905       3.464881
# 2013-09-03        28.3825       3.965188      4.324905       3.464881
# 2013-09-04        28.3825       3.965188      4.324905       3.464881
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2013-09-02       0.795806         1.16645           9.514444
# 2013-09-03       0.795806         1.16645           9.514444
# 2013-09-04       0.795806         1.16645           9.514444
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2013-09-02          2.539781           8.101333          3.857294
# 2013-09-03          2.539781           8.101333          3.857294
# 2013-09-04          2.539781           8.101333          3.857294
#
#             rolling_mean_Level  rolling_std_Level
# date
# 2013-09-02              0.8584           0.102316
# 2013-09-03              0.8584           0.102316
# 2013-09-04              0.8584           0.102316

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
result = adfuller(df["count"])
print(f"ADF Statistics - {result[0]}")
print(f"p-value - {result[1]}")
# Out:
# ADF Statistics - -8.228350535072575
# p-value - 6.158572893204458e-13

# %%
df_log = np.log(df["count"])
plot_pacf(df["count"])
plot_acf(df["count"])
# Out:
# /Users/jennylee/miniforge3/envs/563/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df["rolling_mean_Level"].isna()
# Out:
# date
# 2013-09-02    False
# 2013-09-03    False
# 2013-09-04    False
# 2013-09-05    False
# 2013-09-06    False
#               ...
# 2023-12-27    False
# 2023-12-28    False
# 2023-12-29    False
# 2023-12-30    False
# 2023-12-31    False
# Name: rolling_mean_Level, Length: 3772, dtype: bool

# %%
include_months = [4,5,6,7,8,9]
df = df[df["month"].isin(include_months)]
print(df.shape)
# Out:
# (1859, 19)

# %%
train = df[df["year"] < 2023]
test = df[df["year"] == 2023]
print(train.shape, test.shape)
# Out:
# (3407, 19) (365, 19)

# %%
print(df[df.index >= "2020-01-01"].shape[0])
# Out:
# 1461

# %%
use_for_feats = df.iloc[:,7:20].columns.tolist()
use_for_feats
# Out:
# ['november_Flow',
#  'december_Temp',
#  'january_Temp',
#  'feburary_Temp',
#  'october_Level',
#  'november_Level',
#  'rolling_mean_Temp',
#  'rolling_std_Temp',
#  'rolling_mean_Flow',
#  'rolling_std_Flow',
#  'rolling_mean_Level',
#  'rolling_std_Level']

# %%
# forecaster = ForecasterAutoreg(
#                  regressor = RandomForestRegressor(random_state=123),
#                  lags = 10
#              )

# forecaster.fit(
#     y    = train['count'],
#     exog = train[use_for_feats]
# )

# forecaster

# %%
test
# Out:
#             month  year       Temp     Flow   Level  count  october_Flow  \
# date
# 2023-04-01      4  2023   4.512500  11.5500  1.0580    0.0      0.996387
# 2023-04-02      4  2023   3.695833  10.5450  1.0335    0.0      0.996387
# 2023-04-03      4  2023   2.666667   9.4100  1.0065    0.0      0.996387
# 2023-04-04      4  2023   3.916667   8.5600  0.9835    0.0      0.996387
# 2023-04-05      4  2023   3.887500   7.7500  0.9620    0.0      0.996387
# ...           ...   ...        ...      ...     ...    ...           ...
# 2023-09-26      9  2023  13.229167   0.7195  0.5825    0.0      0.996387
# 2023-09-27      9  2023  12.479167   1.2015  0.6060    0.0      0.996387
# 2023-09-28      9  2023  12.450000   1.8365  0.6275    0.0      0.996387
# 2023-09-29      9  2023   9.529167   1.5055  0.6170    0.0      0.996387
# 2023-09-30      9  2023   9.541667   1.1315  0.6025    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2023-04-01       3.854583        1.01586      4.861828       3.270828
# 2023-04-02       3.854583        1.01586      4.861828       3.270828
# 2023-04-03       3.854583        1.01586      4.861828       3.270828
# 2023-04-04       3.854583        1.01586      4.861828       3.270828
# 2023-04-05       3.854583        1.01586      4.861828       3.270828
# ...                   ...            ...           ...            ...
# 2023-09-26       3.854583        1.01586      4.861828       3.270828
# 2023-09-27       3.854583        1.01586      4.861828       3.270828
# 2023-09-28       3.854583        1.01586      4.861828       3.270828
# 2023-09-29       3.854583        1.01586      4.861828       3.270828
# 2023-09-30       3.854583        1.01586      4.861828       3.270828
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2023-04-01       0.675435        0.829067           5.274028
# 2023-04-02       0.675435        0.829067           5.298056
# 2023-04-03       0.675435        0.829067           5.291667
# 2023-04-04       0.675435        0.829067           5.291111
# 2023-04-05       0.675435        0.829067           5.291111
# ...                   ...             ...                ...
# 2023-09-26       0.675435        0.829067          15.672917
# 2023-09-27       0.675435        0.829067          15.410278
# 2023-09-28       0.675435        0.829067          15.268889
# 2023-09-29       0.675435        0.829067          15.018194
# 2023-09-30       0.675435        0.829067          14.762778
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2023-04-01          1.853413           9.499333          3.111329
# 2023-04-02          1.827066           9.663333          3.028638
# 2023-04-03          1.836203           9.763167          2.966598
# 2023-04-04          1.836631           9.820000          2.925003
# 2023-04-05          1.836631           9.856667          2.890587
# ...                      ...                ...               ...
# 2023-09-26          2.119124           0.287667          0.109644
# 2023-09-27          2.003509           0.320650          0.198734
# 2023-09-28          2.058866           0.373283          0.340186
# 2023-09-29          2.280469           0.414950          0.397059
# 2023-09-30          2.449999           0.443317          0.417019
#
#             rolling_mean_Level  rolling_std_Level
# date
# 2023-04-01            0.996083           0.071829
# 2023-04-02            1.000733           0.069470
# 2023-04-03            1.003583           0.067820
# 2023-04-04            1.005100           0.066804
# 2023-04-05            1.006150           0.065831
# ...                        ...                ...
# 2023-09-26            0.542167           0.011124
# 2023-09-27            0.544383           0.016091
# 2023-09-28            0.547117           0.022122
# 2023-09-29            0.549533           0.025524
# 2023-09-30            0.551350           0.027290
#
# [183 rows x 19 columns]

# %%
df["month"].unique()
# Out:
# array([9, 4, 5, 6, 7, 8])

# %%
df["count"].diff().diff().plot()
# Out:
# <Axes: xlabel='date'>

# %%
# predictions = forecaster.predict(
#                   steps = 330,
#                   exog = test[use_for_feats]
#               )

# predictions.head(3)

# %%
def impute_for_missing(df):
      missing_cols = df.columns[df.isna().any()].tolist()
      for col in missing_cols:
            median_value = df[col].median()
            df[col].fillna(median_value, inplace=True)
      return df

df2 = impute_for_missing(df)
df2
# Out:
#             month  year       Temp       Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273   0.875500  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833   0.790500  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500   0.749000  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500   0.694500  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167   0.668000  0.5280    0.0      7.679129
# ...           ...   ...        ...        ...     ...    ...           ...
# 2023-12-27     12  2023   6.758333  28.499999  1.2440    0.0      0.996387
# 2023-12-28     12  2023   8.962500  30.200000  1.2460    0.0      0.996387
# 2023-12-29     12  2023   8.366667  31.400000  1.2680    0.0      0.996387
# 2023-12-30     12  2023   8.645833  23.600000  1.1695    0.0      0.996387
# 2023-12-31     12  2023   6.516667  18.800000  1.0930    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2013-09-02      28.382500       3.965188      4.324905       3.464881
# 2013-09-03      28.382500       3.965188      4.324905       3.464881
# 2013-09-04      28.382500       3.965188      4.324905       3.464881
# 2013-09-05      28.382500       3.965188      4.324905       3.464881
# 2013-09-06      28.382500       3.965188      4.324905       3.464881
# ...                   ...            ...           ...            ...
# 2023-12-27       3.854583       1.015860      4.861828       3.270828
# 2023-12-28       3.854583       1.015860      4.861828       3.270828
# 2023-12-29       3.854583       1.015860      4.861828       3.270828
# 2023-12-30       3.854583       1.015860      4.861828       3.270828
# 2023-12-31       3.854583       1.015860      4.861828       3.270828
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2013-09-02       0.795806        1.166450           9.514444
# 2013-09-03       0.795806        1.166450           9.514444
# 2013-09-04       0.795806        1.166450           9.514444
# 2013-09-05       0.795806        1.166450           9.514444
# 2013-09-06       0.795806        1.166450           9.514444
# ...                   ...             ...                ...
# 2023-12-27       0.675435        0.829067           5.307917
# 2023-12-28       0.675435        0.829067           5.535972
# 2023-12-29       0.675435        0.829067           5.737222
# 2023-12-30       0.675435        0.829067           5.941250
# 2023-12-31       0.675435        0.829067           6.013611
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2013-09-02          2.539781           8.101333          3.857294
# 2013-09-03          2.539781           8.101333          3.857294
# 2013-09-04          2.539781           8.101333          3.857294
# 2013-09-05          2.539781           8.101333          3.857294
# 2013-09-06          2.539781           8.101333          3.857294
# ...                      ...                ...               ...
# 2023-12-27          2.217812          24.808667         26.852532
# 2023-12-28          2.230511          25.657167         26.597649
# 2023-12-29          2.203401          26.555333         26.310389
# 2023-12-30          2.178952          27.200500         25.979671
# 2023-12-31          2.160107          27.673667         25.681505
#
#             rolling_mean_Level  rolling_std_Level
# date
# 2013-09-02            0.858400           0.102316
# 2013-09-03            0.858400           0.102316
# 2013-09-04            0.858400           0.102316
# 2013-09-05            0.858400           0.102316
# 2013-09-06            0.858400           0.102316
# ...                        ...                ...
# 2023-12-27            1.150467           0.320490
# 2023-12-28            1.166617           0.312316
# 2023-12-29            1.183850           0.302708
# 2023-12-30            1.198083           0.291055
# 2023-12-31            1.209333           0.279657
#
# [3772 rows x 19 columns]

# %%
df["rolling_mean_Level"].isna().sum()
# Out:
# 0

# %%
model = auto_arima(train['count'], 
                   exenous=train[use_for_feats], 
                   seasonal=True, 
                   m=12, 
                   verbose=True)
model
# Out:
# ARIMA(order=(2, 0, 1), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#       suppress_warnings=True)

# %%
sar = SARIMAX(
      endog=df["count"],
      exog=df[use_for_feats],
      order=(2,1,1),
      seasonal_order=(0,0,1,12),
      trend="c"
)

# sar = SARIMAX(
#       endog=train["count"],
#       exog=train[use_for_feats],
#       order=(5,0,5),
#       seasonal_order=(0,0,2,12),
#       trend="c"
# )

results = sar.fit(disp=False)
# Out:
# /Users/jennylee/miniforge3/envs/563/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/jennylee/miniforge3/envs/563/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/jennylee/miniforge3/envs/563/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              count   No. Observations:                 3772
# Model:             SARIMAX(2, 1, 1)x(0, 0, 1, 12)   Log Likelihood              -22473.621
# Date:                            Sun, 09 Jun 2024   AIC                          44983.242
# Time:                                    17:30:20   BIC                          45095.474
# Sample:                                         0   HQIC                         45023.145
#                                            - 3772
# Covariance Type:                              opg
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept             -0.0063      0.361     -0.017      0.986      -0.715       0.702
# november_Flow         -0.0893     93.902     -0.001      0.999    -184.134     183.956
# december_Temp          0.1815    343.624      0.001      1.000    -673.309     673.672
# january_Temp           0.0428    621.758   6.88e-05      1.000   -1218.581    1218.666
# feburary_Temp          0.5168    213.988      0.002      0.998    -418.891     419.925
# october_Level          2.6305   4541.734      0.001      1.000   -8899.005    8904.267
# november_Level         7.2973   7074.540      0.001      0.999   -1.39e+04    1.39e+04
# rolling_mean_Temp     -2.2237      4.388     -0.507      0.612     -10.825       6.377
# rolling_std_Temp      -8.0120      5.565     -1.440      0.150     -18.918       2.894
# rolling_mean_Flow      2.1678      5.732      0.378      0.705      -9.066      13.402
# rolling_std_Flow      -0.4022      6.161     -0.065      0.948     -12.477      11.672
# rolling_mean_Level  -153.3608    228.476     -0.671      0.502    -601.166     294.445
# rolling_std_Level     35.7662    376.297      0.095      0.924    -701.763     773.295
# ar.L1                  0.3768      0.006     64.659      0.000       0.365       0.388
# ar.L2                  0.0730      0.006     13.260      0.000       0.062       0.084
# ma.L1                 -0.9414      0.003   -272.259      0.000      -0.948      -0.935
# ma.S.L12               0.1108      0.005     23.897      0.000       0.102       0.120
# sigma2              8671.3479     55.808    155.377      0.000    8561.965    8780.730
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            389978.33
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             4.06
# Prob(H) (two-sided):                  0.04   Kurtosis:                        52.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
sar_test = test[use_for_feats].iloc[0:5,:]

# %%
df_subset
# Out:
#             month  year       Temp    Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273  0.8755  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833  0.7905  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500  0.7490  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500  0.6945  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167  0.6680  0.5280    0.0      7.679129
# ...           ...   ...        ...     ...     ...    ...           ...
# 2023-09-26      9  2023  13.229167  0.7195  0.5825    0.0      0.996387
# 2023-09-27      9  2023  12.479167  1.2015  0.6060    0.0      0.996387
# 2023-09-28      9  2023  12.450000  1.8365  0.6275    0.0      0.996387
# 2023-09-29      9  2023   9.529167  1.5055  0.6170    0.0      0.996387
# 2023-09-30      9  2023   9.541667  1.1315  0.6025    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2013-09-02      28.382500       3.965188      4.324905       3.464881
# 2013-09-03      28.382500       3.965188      4.324905       3.464881
# 2013-09-04      28.382500       3.965188      4.324905       3.464881
# 2013-09-05      28.382500       3.965188      4.324905       3.464881
# 2013-09-06      28.382500       3.965188      4.324905       3.464881
# ...                   ...            ...           ...            ...
# 2023-09-26       3.854583       1.015860      4.861828       3.270828
# 2023-09-27       3.854583       1.015860      4.861828       3.270828
# 2023-09-28       3.854583       1.015860      4.861828       3.270828
# 2023-09-29       3.854583       1.015860      4.861828       3.270828
# 2023-09-30       3.854583       1.015860      4.861828       3.270828
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2013-09-02       0.795806        1.166450           9.514444
# 2013-09-03       0.795806        1.166450           9.514444
# 2013-09-04       0.795806        1.166450           9.514444
# 2013-09-05       0.795806        1.166450           9.514444
# 2013-09-06       0.795806        1.166450           9.514444
# ...                   ...             ...                ...
# 2023-09-26       0.675435        0.829067          15.672917
# 2023-09-27       0.675435        0.829067          15.410278
# 2023-09-28       0.675435        0.829067          15.268889
# 2023-09-29       0.675435        0.829067          15.018194
# 2023-09-30       0.675435        0.829067          14.762778
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2013-09-02          2.539781           8.101333          3.857294
# 2013-09-03          2.539781           8.101333          3.857294
# 2013-09-04          2.539781           8.101333          3.857294
# 2013-09-05          2.539781           8.101333          3.857294
# 2013-09-06          2.539781           8.101333          3.857294
# ...                      ...                ...               ...
# 2023-09-26          2.119124           0.287667          0.109644
# 2023-09-27          2.003509           0.320650          0.198734
# 2023-09-28          2.058866           0.373283          0.340186
# 2023-09-29          2.280469           0.414950          0.397059
# 2023-09-30          2.449999           0.443317          0.417019
#
#             rolling_mean_Level  rolling_std_Level
# date
# 2013-09-02            0.858400           0.102316
# 2013-09-03            0.858400           0.102316
# 2013-09-04            0.858400           0.102316
# 2013-09-05            0.858400           0.102316
# 2013-09-06            0.858400           0.102316
# ...                        ...                ...
# 2023-09-26            0.542167           0.011124
# 2023-09-27            0.544383           0.016091
# 2023-09-28            0.547117           0.022122
# 2023-09-29            0.549533           0.025524
# 2023-09-30            0.551350           0.027290
#
# [1859 rows x 19 columns]

# %%
results.predict(start=0, end=len(df)-1)
# Out:
# date
# 2013-09-02   -142.724954
# 2013-09-03     -0.589476
# 2013-09-04     -0.311608
# 2013-09-05     -0.253391
# 2013-09-06     -0.215838
#                  ...
# 2023-12-27     -1.778073
# 2023-12-28     -2.786077
# 2023-12-29     -3.138533
# 2023-12-30     -3.683496
# 2023-12-31     -3.923531
# Name: predicted_mean, Length: 3772, dtype: float64

# %%
df["pred"] = results.predict(start=0, end=len(train)-1)
df
# Out:
#             month  year       Temp       Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273   0.875500  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833   0.790500  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500   0.749000  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500   0.694500  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167   0.668000  0.5280    0.0      7.679129
# ...           ...   ...        ...        ...     ...    ...           ...
# 2023-12-27     12  2023   6.758333  28.499999  1.2440    0.0      0.996387
# 2023-12-28     12  2023   8.962500  30.200000  1.2460    0.0      0.996387
# 2023-12-29     12  2023   8.366667  31.400000  1.2680    0.0      0.996387
# 2023-12-30     12  2023   8.645833  23.600000  1.1695    0.0      0.996387
# 2023-12-31     12  2023   6.516667  18.800000  1.0930    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2013-09-02      28.382500       3.965188      4.324905       3.464881
# 2013-09-03      28.382500       3.965188      4.324905       3.464881
# 2013-09-04      28.382500       3.965188      4.324905       3.464881
# 2013-09-05      28.382500       3.965188      4.324905       3.464881
# 2013-09-06      28.382500       3.965188      4.324905       3.464881
# ...                   ...            ...           ...            ...
# 2023-12-27       3.854583       1.015860      4.861828       3.270828
# 2023-12-28       3.854583       1.015860      4.861828       3.270828
# 2023-12-29       3.854583       1.015860      4.861828       3.270828
# 2023-12-30       3.854583       1.015860      4.861828       3.270828
# 2023-12-31       3.854583       1.015860      4.861828       3.270828
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2013-09-02       0.795806        1.166450           9.514444
# 2013-09-03       0.795806        1.166450           9.514444
# 2013-09-04       0.795806        1.166450           9.514444
# 2013-09-05       0.795806        1.166450           9.514444
# 2013-09-06       0.795806        1.166450           9.514444
# ...                   ...             ...                ...
# 2023-12-27       0.675435        0.829067           5.307917
# 2023-12-28       0.675435        0.829067           5.535972
# 2023-12-29       0.675435        0.829067           5.737222
# 2023-12-30       0.675435        0.829067           5.941250
# 2023-12-31       0.675435        0.829067           6.013611
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2013-09-02          2.539781           8.101333          3.857294
# 2013-09-03          2.539781           8.101333          3.857294
# 2013-09-04          2.539781           8.101333          3.857294
# 2013-09-05          2.539781           8.101333          3.857294
# 2013-09-06          2.539781           8.101333          3.857294
# ...                      ...                ...               ...
# 2023-12-27          2.217812          24.808667         26.852532
# 2023-12-28          2.230511          25.657167         26.597649
# 2023-12-29          2.203401          26.555333         26.310389
# 2023-12-30          2.178952          27.200500         25.979671
# 2023-12-31          2.160107          27.673667         25.681505
#
#             rolling_mean_Level  rolling_std_Level        pred
# date
# 2013-09-02            0.858400           0.102316 -142.724954
# 2013-09-03            0.858400           0.102316   -0.589476
# 2013-09-04            0.858400           0.102316   -0.311608
# 2013-09-05            0.858400           0.102316   -0.253391
# 2013-09-06            0.858400           0.102316   -0.215838
# ...                        ...                ...         ...
# 2023-12-27            1.150467           0.320490         NaN
# 2023-12-28            1.166617           0.312316         NaN
# 2023-12-29            1.183850           0.302708         NaN
# 2023-12-30            1.198083           0.291055         NaN
# 2023-12-31            1.209333           0.279657         NaN
#
# [3772 rows x 20 columns]

# %%
adjust_val = lambda row: 0 if row["pred"] <= 0 else row["pred"]
df["pred_adjust"] = df.apply(adjust_val, axis=1)
df
# Out:
#             month  year       Temp       Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273   0.875500  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833   0.790500  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500   0.749000  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500   0.694500  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167   0.668000  0.5280    0.0      7.679129
# ...           ...   ...        ...        ...     ...    ...           ...
# 2023-12-27     12  2023   6.758333  28.499999  1.2440    0.0      0.996387
# 2023-12-28     12  2023   8.962500  30.200000  1.2460    0.0      0.996387
# 2023-12-29     12  2023   8.366667  31.400000  1.2680    0.0      0.996387
# 2023-12-30     12  2023   8.645833  23.600000  1.1695    0.0      0.996387
# 2023-12-31     12  2023   6.516667  18.800000  1.0930    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  ...  october_Level  \
# date                                                    ...
# 2013-09-02      28.382500       3.965188      4.324905  ...       0.795806
# 2013-09-03      28.382500       3.965188      4.324905  ...       0.795806
# 2013-09-04      28.382500       3.965188      4.324905  ...       0.795806
# 2013-09-05      28.382500       3.965188      4.324905  ...       0.795806
# 2013-09-06      28.382500       3.965188      4.324905  ...       0.795806
# ...                   ...            ...           ...  ...            ...
# 2023-12-27       3.854583       1.015860      4.861828  ...       0.675435
# 2023-12-28       3.854583       1.015860      4.861828  ...       0.675435
# 2023-12-29       3.854583       1.015860      4.861828  ...       0.675435
# 2023-12-30       3.854583       1.015860      4.861828  ...       0.675435
# 2023-12-31       3.854583       1.015860      4.861828  ...       0.675435
#
#             november_Level  rolling_mean_Temp  rolling_std_Temp  \
# date
# 2013-09-02        1.166450           9.514444          2.539781
# 2013-09-03        1.166450           9.514444          2.539781
# 2013-09-04        1.166450           9.514444          2.539781
# 2013-09-05        1.166450           9.514444          2.539781
# 2013-09-06        1.166450           9.514444          2.539781
# ...                    ...                ...               ...
# 2023-12-27        0.829067           5.307917          2.217812
# 2023-12-28        0.829067           5.535972          2.230511
# 2023-12-29        0.829067           5.737222          2.203401
# 2023-12-30        0.829067           5.941250          2.178952
# 2023-12-31        0.829067           6.013611          2.160107
#
#             rolling_mean_Flow  rolling_std_Flow  rolling_mean_Level  \
# date
# 2013-09-02           8.101333          3.857294            0.858400
# 2013-09-03           8.101333          3.857294            0.858400
# 2013-09-04           8.101333          3.857294            0.858400
# 2013-09-05           8.101333          3.857294            0.858400
# 2013-09-06           8.101333          3.857294            0.858400
# ...                       ...               ...                 ...
# 2023-12-27          24.808667         26.852532            1.150467
# 2023-12-28          25.657167         26.597649            1.166617
# 2023-12-29          26.555333         26.310389            1.183850
# 2023-12-30          27.200500         25.979671            1.198083
# 2023-12-31          27.673667         25.681505            1.209333
#
#             rolling_std_Level        pred  pred_adjust
# date
# 2013-09-02           0.102316 -142.724954          0.0
# 2013-09-03           0.102316   -0.589476          0.0
# 2013-09-04           0.102316   -0.311608          0.0
# 2013-09-05           0.102316   -0.253391          0.0
# 2013-09-06           0.102316   -0.215838          0.0
# ...                       ...         ...          ...
# 2023-12-27           0.320490         NaN          NaN
# 2023-12-28           0.312316         NaN          NaN
# 2023-12-29           0.302708         NaN          NaN
# 2023-12-30           0.291055         NaN          NaN
# 2023-12-31           0.279657         NaN          NaN
#
# [3772 rows x 21 columns]

# %%
viz_df = train["pred_adjust"]
viz_df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
def count_total_diff(df):
      df["diff"] = abs(df["pred_adjust"] - df["count"])
      total_diff = df["diff"].sum()
      total_matching_zeros = len(df[(df["count"] == 0) & (df["pred_adjust"] == 0)])
      return total_diff, total_matching_zeros

def evaluate_model(df):
      mae = mean_absolute_error(df['count'], df['pred_adjust'])
      mse = mean_squared_error(df['count'], df['pred_adjust'])
      rmse = np.sqrt(mse)
      return mae, mse, rmse

count_total_diff(df)
evaluate_model(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[467], line 14
#      11       return mae, mse, rmse
#      13 count_total_diff(df)
# ---> 14 evaluate_model(df)
#
# Cell In[467], line 8, in evaluate_model(df)
#       7 def evaluate_model(df):
# ----> 8       mae = mean_absolute_error(df['count'], df['pred_adjust'])
#       9       mse = mean_squared_error(df['count'], df['pred_adjust'])
#      10       rmse = np.sqrt(mse)
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/sklearn/metrics/_regression.py:207, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     143 @validate_params(
#     144     {
#     145         "y_true": ["array-like"],
#    (...)
#     153     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     154 ):
#     155     """Mean absolute error regression loss.
#     156
#     157     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     205     0.85...
#     206     """
# --> 207     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     208         y_true, y_pred, multioutput
#     209     )
#     210     check_consistent_length(y_true, y_pred, sample_weight)
#     211     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/sklearn/metrics/_regression.py:104, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     102 check_consistent_length(y_true, y_pred)
#     103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     106 if y_true.ndim == 1:
#     107     y_true = y_true.reshape((-1, 1))
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/sklearn/utils/validation.py:1003, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     997     raise ValueError(
#     998         "Found array with dim %d. %s expected <= 2."
#     999         % (array.ndim, estimator_name)
#    1000     )
#    1002 if force_all_finite:
# -> 1003     _assert_all_finite(
#    1004         array,
#    1005         input_name=input_name,
#    1006         estimator_name=estimator_name,
#    1007         allow_nan=force_all_finite == "allow-nan",
#    1008     )
#    1010 if copy:
#    1011     if _is_numpy_namespace(xp):
#    1012         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
df_2022 = df[df["year"] == 2022]

plt.figure(figsize=(12, 6))
plt.plot(df_2022.index, df_2022['count'], label='Prediction', color='blue')
plt.plot(df_2022.index, df_2022['pred_adjust'], label='Adjusted Prediction', color='red')

# Adding title and labels
plt.title('Prediction and Adjusted Prediction In 2022')
plt.xlabel('Date')
plt.ylabel('Values')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
train.head(5)
# Out:
#             month  year       Temp    Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273  0.8755  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833  0.7905  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500  0.7490  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500  0.6945  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167  0.6680  0.5280    0.0      7.679129
#
#             november_Flow  december_Temp  january_Temp  ...  november_Level  \
# date                                                    ...
# 2013-09-02        28.3825       3.965188      4.324905  ...         1.16645
# 2013-09-03        28.3825       3.965188      4.324905  ...         1.16645
# 2013-09-04        28.3825       3.965188      4.324905  ...         1.16645
# 2013-09-05        28.3825       3.965188      4.324905  ...         1.16645
# 2013-09-06        28.3825       3.965188      4.324905  ...         1.16645
#
#             rolling_mean_Temp  rolling_std_Temp  rolling_mean_Flow  \
# date
# 2013-09-02           9.514444          2.539781           8.101333
# 2013-09-03           9.514444          2.539781           8.101333
# 2013-09-04           9.514444          2.539781           8.101333
# 2013-09-05           9.514444          2.539781           8.101333
# 2013-09-06           9.514444          2.539781           8.101333
#
#             rolling_std_Flow  rolling_mean_Level  rolling_std_Level  \
# date
# 2013-09-02          3.857294              0.8584           0.102316
# 2013-09-03          3.857294              0.8584           0.102316
# 2013-09-04          3.857294              0.8584           0.102316
# 2013-09-05          3.857294              0.8584           0.102316
# 2013-09-06          3.857294              0.8584           0.102316
#
#                   pred  pred_adjust  diff
# date
# 2013-09-02 -602.761941          0.0   0.0
# 2013-09-03   -5.004246          0.0   0.0
# 2013-09-04   -2.816892          0.0   0.0
# 2013-09-05   -2.188467          0.0   0.0
# 2013-09-06   -1.784372          0.0   0.0
#
# [5 rows x 22 columns]

# %%
def find_date(df, real_count, observe_num=5, max_repeat=5):
    df = df.reset_index()
    repeat_count = 0
    real_date = "Not defined"

    for ind, row in df.iterrows():
        if ind == 0:
            continue
        
        print(f" Ind: {ind}, Date: {row['date']}, Count: {row[real_count]}")

        if (row[real_count] >= observe_num) & (df.loc[ind-1, real_count] >= observe_num):
            print(f"----------------------{repeat_count}-----------------------")
            repeat_count += 1
        else:
            repeat_count = 0

        if repeat_count == max_repeat:
            print(f"Stopping at: {ind}, Date: {row['date']}")
            real_date = df.loc[ind, "date"]
            break

    return real_date

real_date = find_date(df_2023, "pred_adjust", 5, 4)
# Out:
#  Ind: 1, Date: 2023-01-02 00:00:00, Count: 0.0
#  Ind: 2, Date: 2023-01-03 00:00:00, Count: 0.0
#  Ind: 3, Date: 2023-01-04 00:00:00, Count: 0.0
#  Ind: 4, Date: 2023-01-05 00:00:00, Count: 0.0
#  Ind: 5, Date: 2023-01-06 00:00:00, Count: 0.0
#  Ind: 6, Date: 2023-01-07 00:00:00, Count: 0.0
#  Ind: 7, Date: 2023-01-08 00:00:00, Count: 0.0
#  Ind: 8, Date: 2023-01-09 00:00:00, Count: 0.0
#  Ind: 9, Date: 2023-01-10 00:00:00, Count: 0.0
#  Ind: 10, Date: 2023-01-11 00:00:00, Count: 0.0
#  Ind: 11, Date: 2023-01-12 00:00:00, Count: 0.0
#  Ind: 12, Date: 2023-01-13 00:00:00, Count: 0.0
#  Ind: 13, Date: 2023-01-14 00:00:00, Count: 0.0
#  Ind: 14, Date: 2023-01-15 00:00:00, Count: 0.0
#  Ind: 15, Date: 2023-01-16 00:00:00, Count: 0.0
#  Ind: 16, Date: 2023-01-17 00:00:00, Count: 0.0
#  Ind: 17, Date: 2023-01-18 00:00:00, Count: 0.0
#  Ind: 18, Date: 2023-01-19 00:00:00, Count: 0.0
#  Ind: 19, Date: 2023-01-20 00:00:00, Count: 0.0
#  Ind: 20, Date: 2023-01-21 00:00:00, Count: 8.0
#  Ind: 21, Date: 2023-01-22 00:00:00, Count: 8.0
# ----------------------0-----------------------
#  Ind: 22, Date: 2023-01-23 00:00:00, Count: 7.0
# ----------------------1-----------------------
#  Ind: 23, Date: 2023-01-24 00:00:00, Count: 6.0
# ----------------------2-----------------------
#  Ind: 24, Date: 2023-01-25 00:00:00, Count: 3.0
#  Ind: 25, Date: 2023-01-26 00:00:00, Count: 2.0
#  Ind: 26, Date: 2023-01-27 00:00:00, Count: 2.0
#  Ind: 27, Date: 2023-01-28 00:00:00, Count: 3.0
#  Ind: 28, Date: 2023-01-29 00:00:00, Count: 1.0
#  Ind: 29, Date: 2023-01-30 00:00:00, Count: 0.0
#  Ind: 30, Date: 2023-01-31 00:00:00, Count: 0.0
#  Ind: 31, Date: 2023-02-01 00:00:00, Count: 0.0
#  Ind: 32, Date: 2023-02-02 00:00:00, Count: 0.0
#  Ind: 33, Date: 2023-02-03 00:00:00, Count: 0.0
#  Ind: 34, Date: 2023-02-04 00:00:00, Count: 1.0
#  Ind: 35, Date: 2023-02-05 00:00:00, Count: 1.0
#  Ind: 36, Date: 2023-02-06 00:00:00, Count: 1.0
#  Ind: 37, Date: 2023-02-07 00:00:00, Count: 1.0
#  Ind: 38, Date: 2023-02-08 00:00:00, Count: 1.0
#  Ind: 39, Date: 2023-02-09 00:00:00, Count: 0.0
#  Ind: 40, Date: 2023-02-10 00:00:00, Count: 0.0
#  Ind: 41, Date: 2023-02-11 00:00:00, Count: 0.0
#  Ind: 42, Date: 2023-02-12 00:00:00, Count: 0.0
#  Ind: 43, Date: 2023-02-13 00:00:00, Count: 0.0
#  Ind: 44, Date: 2023-02-14 00:00:00, Count: 0.0
#  Ind: 45, Date: 2023-02-15 00:00:00, Count: 0.0
#  Ind: 46, Date: 2023-02-16 00:00:00, Count: 0.0
#  Ind: 47, Date: 2023-02-17 00:00:00, Count: 1.0
#  Ind: 48, Date: 2023-02-18 00:00:00, Count: 1.0
#  Ind: 49, Date: 2023-02-19 00:00:00, Count: 1.0
#  Ind: 50, Date: 2023-02-20 00:00:00, Count: 0.0
#  Ind: 51, Date: 2023-02-21 00:00:00, Count: 0.0
#  Ind: 52, Date: 2023-02-22 00:00:00, Count: 0.0
#  Ind: 53, Date: 2023-02-23 00:00:00, Count: 0.0
#  Ind: 54, Date: 2023-02-24 00:00:00, Count: 0.0
#  Ind: 55, Date: 2023-02-25 00:00:00, Count: 0.0
#  Ind: 56, Date: 2023-02-26 00:00:00, Count: 0.0
#  Ind: 57, Date: 2023-02-27 00:00:00, Count: 0.0
#  Ind: 58, Date: 2023-02-28 00:00:00, Count: 0.0
#  Ind: 59, Date: 2023-03-01 00:00:00, Count: 0.0
#  Ind: 60, Date: 2023-03-02 00:00:00, Count: 0.0
#  Ind: 61, Date: 2023-03-03 00:00:00, Count: 0.0
#  Ind: 62, Date: 2023-03-04 00:00:00, Count: 0.0
#  Ind: 63, Date: 2023-03-05 00:00:00, Count: 0.0
#  Ind: 64, Date: 2023-03-06 00:00:00, Count: 0.0
#  Ind: 65, Date: 2023-03-07 00:00:00, Count: 0.0
#  Ind: 66, Date: 2023-03-08 00:00:00, Count: 1.0
#  Ind: 67, Date: 2023-03-09 00:00:00, Count: 2.0
#  Ind: 68, Date: 2023-03-10 00:00:00, Count: 1.0
#  Ind: 69, Date: 2023-03-11 00:00:00, Count: 1.0
#  Ind: 70, Date: 2023-03-12 00:00:00, Count: 2.0
#  Ind: 71, Date: 2023-03-13 00:00:00, Count: 1.0
#  Ind: 72, Date: 2023-03-14 00:00:00, Count: 1.0
#  Ind: 73, Date: 2023-03-15 00:00:00, Count: 1.0
#  Ind: 74, Date: 2023-03-16 00:00:00, Count: 1.0
#  Ind: 75, Date: 2023-03-17 00:00:00, Count: 1.0
#  Ind: 76, Date: 2023-03-18 00:00:00, Count: 0.0
#  Ind: 77, Date: 2023-03-19 00:00:00, Count: 0.0
#  Ind: 78, Date: 2023-03-20 00:00:00, Count: 0.0
#  Ind: 79, Date: 2023-03-21 00:00:00, Count: 0.0
#  Ind: 80, Date: 2023-03-22 00:00:00, Count: 0.0
#  Ind: 81, Date: 2023-03-23 00:00:00, Count: 0.0
#  Ind: 82, Date: 2023-03-24 00:00:00, Count: 0.0
#  Ind: 83, Date: 2023-03-25 00:00:00, Count: 0.0
#  Ind: 84, Date: 2023-03-26 00:00:00, Count: 2.0
#  Ind: 85, Date: 2023-03-27 00:00:00, Count: 4.0
#  Ind: 86, Date: 2023-03-28 00:00:00, Count: 3.0
#  Ind: 87, Date: 2023-03-29 00:00:00, Count: 2.0
#  Ind: 88, Date: 2023-03-30 00:00:00, Count: 2.0
#  Ind: 89, Date: 2023-03-31 00:00:00, Count: 3.0
#  Ind: 90, Date: 2023-04-01 00:00:00, Count: 2.0
#  Ind: 91, Date: 2023-04-02 00:00:00, Count: 2.0
#  Ind: 92, Date: 2023-04-03 00:00:00, Count: 1.0
#  Ind: 93, Date: 2023-04-04 00:00:00, Count: 1.0
#  Ind: 94, Date: 2023-04-05 00:00:00, Count: 1.0
#  Ind: 95, Date: 2023-04-06 00:00:00, Count: 0.0
#  Ind: 96, Date: 2023-04-07 00:00:00, Count: 0.0
#  Ind: 97, Date: 2023-04-08 00:00:00, Count: 0.0
#  Ind: 98, Date: 2023-04-09 00:00:00, Count: 0.0
#  Ind: 99, Date: 2023-04-10 00:00:00, Count: 0.0
#  Ind: 100, Date: 2023-04-11 00:00:00, Count: 0.0
#  Ind: 101, Date: 2023-04-12 00:00:00, Count: 0.0
#  Ind: 102, Date: 2023-04-13 00:00:00, Count: 0.0
#  Ind: 103, Date: 2023-04-14 00:00:00, Count: 0.0
#  Ind: 104, Date: 2023-04-15 00:00:00, Count: 0.0
#  Ind: 105, Date: 2023-04-16 00:00:00, Count: 0.0
#  Ind: 106, Date: 2023-04-17 00:00:00, Count: 0.0
#  Ind: 107, Date: 2023-04-18 00:00:00, Count: 0.0
#  Ind: 108, Date: 2023-04-19 00:00:00, Count: 0.0
#  Ind: 109, Date: 2023-04-20 00:00:00, Count: 0.0
#  Ind: 110, Date: 2023-04-21 00:00:00, Count: 0.0
#  Ind: 111, Date: 2023-04-22 00:00:00, Count: 0.0
#  Ind: 112, Date: 2023-04-23 00:00:00, Count: 0.0
#  Ind: 113, Date: 2023-04-24 00:00:00, Count: 0.0
#  Ind: 114, Date: 2023-04-25 00:00:00, Count: 0.0
#  Ind: 115, Date: 2023-04-26 00:00:00, Count: 0.0
#  Ind: 116, Date: 2023-04-27 00:00:00, Count: 0.0
#  Ind: 117, Date: 2023-04-28 00:00:00, Count: 0.0
#  Ind: 118, Date: 2023-04-29 00:00:00, Count: 0.0
#  Ind: 119, Date: 2023-04-30 00:00:00, Count: 0.0
#  Ind: 120, Date: 2023-05-01 00:00:00, Count: 0.0
#  Ind: 121, Date: 2023-05-02 00:00:00, Count: 0.0
#  Ind: 122, Date: 2023-05-03 00:00:00, Count: 0.0
#  Ind: 123, Date: 2023-05-04 00:00:00, Count: 2.0
#  Ind: 124, Date: 2023-05-05 00:00:00, Count: 0.0
#  Ind: 125, Date: 2023-05-06 00:00:00, Count: 15.0
#  Ind: 126, Date: 2023-05-07 00:00:00, Count: 0.0
#  Ind: 127, Date: 2023-05-08 00:00:00, Count: 0.0
#  Ind: 128, Date: 2023-05-09 00:00:00, Count: 45.0
#  Ind: 129, Date: 2023-05-10 00:00:00, Count: 6.0
# ----------------------0-----------------------
#  Ind: 130, Date: 2023-05-11 00:00:00, Count: 76.0
# ----------------------1-----------------------
#  Ind: 131, Date: 2023-05-12 00:00:00, Count: 13.0
# ----------------------2-----------------------
#  Ind: 132, Date: 2023-05-13 00:00:00, Count: 98.0
# ----------------------3-----------------------
# Stopping at: 132, Date: 2023-05-13 00:00:00

# %%
for year in df["year"].unique().tolist():
      df_year = df[df["year"] == year]
      quantile_10 = df_year["count"].quantile(0.9)
      print(quantile_10)
# Out:
# 0.0
# 3.0
# 10.400000000000091
# 43.0
# 0.0
# 0.0
# 10.600000000000023
# 3.0
# 0.0
# 0.0
# 0.0

# %%
find_date(df_2023, "count", 5, 2)
# Out:
#  Ind: 1, Date: 2023-01-02 00:00:00, Count: 0.0
#  Ind: 2, Date: 2023-01-03 00:00:00, Count: 0.0
#  Ind: 3, Date: 2023-01-04 00:00:00, Count: 0.0
#  Ind: 4, Date: 2023-01-05 00:00:00, Count: 0.0
#  Ind: 5, Date: 2023-01-06 00:00:00, Count: 0.0
#  Ind: 6, Date: 2023-01-07 00:00:00, Count: 0.0
#  Ind: 7, Date: 2023-01-08 00:00:00, Count: 0.0
#  Ind: 8, Date: 2023-01-09 00:00:00, Count: 0.0
#  Ind: 9, Date: 2023-01-10 00:00:00, Count: 0.0
#  Ind: 10, Date: 2023-01-11 00:00:00, Count: 0.0
#  Ind: 11, Date: 2023-01-12 00:00:00, Count: 0.0
#  Ind: 12, Date: 2023-01-13 00:00:00, Count: 0.0
#  Ind: 13, Date: 2023-01-14 00:00:00, Count: 0.0
#  Ind: 14, Date: 2023-01-15 00:00:00, Count: 0.0
#  Ind: 15, Date: 2023-01-16 00:00:00, Count: 0.0
#  Ind: 16, Date: 2023-01-17 00:00:00, Count: 0.0
#  Ind: 17, Date: 2023-01-18 00:00:00, Count: 0.0
#  Ind: 18, Date: 2023-01-19 00:00:00, Count: 0.0
#  Ind: 19, Date: 2023-01-20 00:00:00, Count: 0.0
#  Ind: 20, Date: 2023-01-21 00:00:00, Count: 0.0
#  Ind: 21, Date: 2023-01-22 00:00:00, Count: 0.0
#  Ind: 22, Date: 2023-01-23 00:00:00, Count: 0.0
#  Ind: 23, Date: 2023-01-24 00:00:00, Count: 0.0
#  Ind: 24, Date: 2023-01-25 00:00:00, Count: 0.0
#  Ind: 25, Date: 2023-01-26 00:00:00, Count: 0.0
#  Ind: 26, Date: 2023-01-27 00:00:00, Count: 0.0
#  Ind: 27, Date: 2023-01-28 00:00:00, Count: 0.0
#  Ind: 28, Date: 2023-01-29 00:00:00, Count: 0.0
#  Ind: 29, Date: 2023-01-30 00:00:00, Count: 0.0
#  Ind: 30, Date: 2023-01-31 00:00:00, Count: 0.0
#  Ind: 31, Date: 2023-02-01 00:00:00, Count: 0.0
#  Ind: 32, Date: 2023-02-02 00:00:00, Count: 0.0
#  Ind: 33, Date: 2023-02-03 00:00:00, Count: 0.0
#  Ind: 34, Date: 2023-02-04 00:00:00, Count: 0.0
#  Ind: 35, Date: 2023-02-05 00:00:00, Count: 0.0
#  Ind: 36, Date: 2023-02-06 00:00:00, Count: 0.0
#  Ind: 37, Date: 2023-02-07 00:00:00, Count: 0.0
#  Ind: 38, Date: 2023-02-08 00:00:00, Count: 0.0
#  Ind: 39, Date: 2023-02-09 00:00:00, Count: 0.0
#  Ind: 40, Date: 2023-02-10 00:00:00, Count: 0.0
#  Ind: 41, Date: 2023-02-11 00:00:00, Count: 0.0
#  Ind: 42, Date: 2023-02-12 00:00:00, Count: 0.0
#  Ind: 43, Date: 2023-02-13 00:00:00, Count: 0.0
#  Ind: 44, Date: 2023-02-14 00:00:00, Count: 0.0
#  Ind: 45, Date: 2023-02-15 00:00:00, Count: 0.0
#  Ind: 46, Date: 2023-02-16 00:00:00, Count: 0.0
#  Ind: 47, Date: 2023-02-17 00:00:00, Count: 0.0
#  Ind: 48, Date: 2023-02-18 00:00:00, Count: 0.0
#  Ind: 49, Date: 2023-02-19 00:00:00, Count: 0.0
#  Ind: 50, Date: 2023-02-20 00:00:00, Count: 0.0
#  Ind: 51, Date: 2023-02-21 00:00:00, Count: 0.0
#  Ind: 52, Date: 2023-02-22 00:00:00, Count: 0.0
#  Ind: 53, Date: 2023-02-23 00:00:00, Count: 0.0
#  Ind: 54, Date: 2023-02-24 00:00:00, Count: 0.0
#  Ind: 55, Date: 2023-02-25 00:00:00, Count: 0.0
#  Ind: 56, Date: 2023-02-26 00:00:00, Count: 0.0
#  Ind: 57, Date: 2023-02-27 00:00:00, Count: 0.0
#  Ind: 58, Date: 2023-02-28 00:00:00, Count: 0.0
#  Ind: 59, Date: 2023-03-01 00:00:00, Count: 0.0
#  Ind: 60, Date: 2023-03-02 00:00:00, Count: 0.0
#  Ind: 61, Date: 2023-03-03 00:00:00, Count: 0.0
#  Ind: 62, Date: 2023-03-04 00:00:00, Count: 0.0
#  Ind: 63, Date: 2023-03-05 00:00:00, Count: 0.0
#  Ind: 64, Date: 2023-03-06 00:00:00, Count: 0.0
#  Ind: 65, Date: 2023-03-07 00:00:00, Count: 0.0
#  Ind: 66, Date: 2023-03-08 00:00:00, Count: 0.0
#  Ind: 67, Date: 2023-03-09 00:00:00, Count: 0.0
#  Ind: 68, Date: 2023-03-10 00:00:00, Count: 0.0
#  Ind: 69, Date: 2023-03-11 00:00:00, Count: 0.0
#  Ind: 70, Date: 2023-03-12 00:00:00, Count: 0.0
#  Ind: 71, Date: 2023-03-13 00:00:00, Count: 0.0
#  Ind: 72, Date: 2023-03-14 00:00:00, Count: 0.0
#  Ind: 73, Date: 2023-03-15 00:00:00, Count: 0.0
#  Ind: 74, Date: 2023-03-16 00:00:00, Count: 0.0
#  Ind: 75, Date: 2023-03-17 00:00:00, Count: 0.0
#  Ind: 76, Date: 2023-03-18 00:00:00, Count: 0.0
#  Ind: 77, Date: 2023-03-19 00:00:00, Count: 0.0
#  Ind: 78, Date: 2023-03-20 00:00:00, Count: 0.0
#  Ind: 79, Date: 2023-03-21 00:00:00, Count: 0.0
#  Ind: 80, Date: 2023-03-22 00:00:00, Count: 0.0
#  Ind: 81, Date: 2023-03-23 00:00:00, Count: 0.0
#  Ind: 82, Date: 2023-03-24 00:00:00, Count: 0.0
#  Ind: 83, Date: 2023-03-25 00:00:00, Count: 0.0
#  Ind: 84, Date: 2023-03-26 00:00:00, Count: 0.0
#  Ind: 85, Date: 2023-03-27 00:00:00, Count: 0.0
#  Ind: 86, Date: 2023-03-28 00:00:00, Count: 0.0
#  Ind: 87, Date: 2023-03-29 00:00:00, Count: 0.0
#  Ind: 88, Date: 2023-03-30 00:00:00, Count: 0.0
#  Ind: 89, Date: 2023-03-31 00:00:00, Count: 0.0
#  Ind: 90, Date: 2023-04-01 00:00:00, Count: 0.0
#  Ind: 91, Date: 2023-04-02 00:00:00, Count: 0.0
#  Ind: 92, Date: 2023-04-03 00:00:00, Count: 0.0
#  Ind: 93, Date: 2023-04-04 00:00:00, Count: 0.0
#  Ind: 94, Date: 2023-04-05 00:00:00, Count: 0.0
#  Ind: 95, Date: 2023-04-06 00:00:00, Count: 0.0
#  Ind: 96, Date: 2023-04-07 00:00:00, Count: 0.0
#  Ind: 97, Date: 2023-04-08 00:00:00, Count: 0.0
#  Ind: 98, Date: 2023-04-09 00:00:00, Count: 0.0
#  Ind: 99, Date: 2023-04-10 00:00:00, Count: 0.0
#  Ind: 100, Date: 2023-04-11 00:00:00, Count: 0.0
#  Ind: 101, Date: 2023-04-12 00:00:00, Count: 0.0
#  Ind: 102, Date: 2023-04-13 00:00:00, Count: 0.0
#  Ind: 103, Date: 2023-04-14 00:00:00, Count: 0.0
#  Ind: 104, Date: 2023-04-15 00:00:00, Count: 0.0
#  Ind: 105, Date: 2023-04-16 00:00:00, Count: 0.0
#  Ind: 106, Date: 2023-04-17 00:00:00, Count: 0.0
#  Ind: 107, Date: 2023-04-18 00:00:00, Count: 0.0
#  Ind: 108, Date: 2023-04-19 00:00:00, Count: 0.0
#  Ind: 109, Date: 2023-04-20 00:00:00, Count: 0.0
#  Ind: 110, Date: 2023-04-21 00:00:00, Count: 0.0
#  Ind: 111, Date: 2023-04-22 00:00:00, Count: 0.0
#  Ind: 112, Date: 2023-04-23 00:00:00, Count: 0.0
#  Ind: 113, Date: 2023-04-24 00:00:00, Count: 0.0
#  Ind: 114, Date: 2023-04-25 00:00:00, Count: 0.0
#  Ind: 115, Date: 2023-04-26 00:00:00, Count: 0.0
#  Ind: 116, Date: 2023-04-27 00:00:00, Count: 0.0
#  Ind: 117, Date: 2023-04-28 00:00:00, Count: 0.0
#  Ind: 118, Date: 2023-04-29 00:00:00, Count: 0.0
#  Ind: 119, Date: 2023-04-30 00:00:00, Count: 0.0
#  Ind: 120, Date: 2023-05-01 00:00:00, Count: 0.0
#  Ind: 121, Date: 2023-05-02 00:00:00, Count: 0.0
#  Ind: 122, Date: 2023-05-03 00:00:00, Count: 20.0
#  Ind: 123, Date: 2023-05-04 00:00:00, Count: 0.0
#  Ind: 124, Date: 2023-05-05 00:00:00, Count: 43.0
#  Ind: 125, Date: 2023-05-06 00:00:00, Count: 0.0
#  Ind: 126, Date: 2023-05-07 00:00:00, Count: 0.0
#  Ind: 127, Date: 2023-05-08 00:00:00, Count: 104.0
#  Ind: 128, Date: 2023-05-09 00:00:00, Count: 0.0
#  Ind: 129, Date: 2023-05-10 00:00:00, Count: 161.0
#  Ind: 130, Date: 2023-05-11 00:00:00, Count: 0.0
#  Ind: 131, Date: 2023-05-12 00:00:00, Count: 197.0
#  Ind: 132, Date: 2023-05-13 00:00:00, Count: 0.0
#  Ind: 133, Date: 2023-05-14 00:00:00, Count: 0.0
#  Ind: 134, Date: 2023-05-15 00:00:00, Count: 162.0
#  Ind: 135, Date: 2023-05-16 00:00:00, Count: 0.0
#  Ind: 136, Date: 2023-05-17 00:00:00, Count: 45.0
#  Ind: 137, Date: 2023-05-18 00:00:00, Count: 0.0
#  Ind: 138, Date: 2023-05-19 00:00:00, Count: 73.0
#  Ind: 139, Date: 2023-05-20 00:00:00, Count: 0.0
#  Ind: 140, Date: 2023-05-21 00:00:00, Count: 0.0
#  Ind: 141, Date: 2023-05-22 00:00:00, Count: 0.0
#  Ind: 142, Date: 2023-05-23 00:00:00, Count: 34.0
#  Ind: 143, Date: 2023-05-24 00:00:00, Count: 0.0
#  Ind: 144, Date: 2023-05-25 00:00:00, Count: 0.0
#  Ind: 145, Date: 2023-05-26 00:00:00, Count: 617.0
#  Ind: 146, Date: 2023-05-27 00:00:00, Count: 0.0
#  Ind: 147, Date: 2023-05-28 00:00:00, Count: 0.0
#  Ind: 148, Date: 2023-05-29 00:00:00, Count: 0.0
#  Ind: 149, Date: 2023-05-30 00:00:00, Count: 976.0
#  Ind: 150, Date: 2023-05-31 00:00:00, Count: 635.0
# ----------------------0-----------------------
#  Ind: 151, Date: 2023-06-01 00:00:00, Count: 794.0
# ----------------------1-----------------------
# Stopping at: 151, Date: 2023-06-01 00:00:00
# Timestamp('2023-06-01 00:00:00')

# %%
df
# Out:
#             month  year       Temp       Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273   0.875500  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833   0.790500  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500   0.749000  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500   0.694500  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167   0.668000  0.5280    0.0      7.679129
# ...           ...   ...        ...        ...     ...    ...           ...
# 2023-12-27     12  2023   6.758333  28.499999  1.2440    0.0      0.996387
# 2023-12-28     12  2023   8.962500  30.200000  1.2460    0.0      0.996387
# 2023-12-29     12  2023   8.366667  31.400000  1.2680    0.0      0.996387
# 2023-12-30     12  2023   8.645833  23.600000  1.1695    0.0      0.996387
# 2023-12-31     12  2023   6.516667  18.800000  1.0930    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  ...  november_Level  \
# date                                                    ...
# 2013-09-02      28.382500       3.965188      4.324905  ...        1.166450
# 2013-09-03      28.382500       3.965188      4.324905  ...        1.166450
# 2013-09-04      28.382500       3.965188      4.324905  ...        1.166450
# 2013-09-05      28.382500       3.965188      4.324905  ...        1.166450
# 2013-09-06      28.382500       3.965188      4.324905  ...        1.166450
# ...                   ...            ...           ...  ...             ...
# 2023-12-27       3.854583       1.015860      4.861828  ...        0.829067
# 2023-12-28       3.854583       1.015860      4.861828  ...        0.829067
# 2023-12-29       3.854583       1.015860      4.861828  ...        0.829067
# 2023-12-30       3.854583       1.015860      4.861828  ...        0.829067
# 2023-12-31       3.854583       1.015860      4.861828  ...        0.829067
#
#             rolling_mean_Temp  rolling_std_Temp  rolling_mean_Flow  \
# date
# 2013-09-02           9.514444          2.539781           8.101333
# 2013-09-03           9.514444          2.539781           8.101333
# 2013-09-04           9.514444          2.539781           8.101333
# 2013-09-05           9.514444          2.539781           8.101333
# 2013-09-06           9.514444          2.539781           8.101333
# ...                       ...               ...                ...
# 2023-12-27           5.307917          2.217812          24.808667
# 2023-12-28           5.535972          2.230511          25.657167
# 2023-12-29           5.737222          2.203401          26.555333
# 2023-12-30           5.941250          2.178952          27.200500
# 2023-12-31           6.013611          2.160107          27.673667
#
#             rolling_std_Flow  rolling_mean_Level  rolling_std_Level  \
# date
# 2013-09-02          3.857294            0.858400           0.102316
# 2013-09-03          3.857294            0.858400           0.102316
# 2013-09-04          3.857294            0.858400           0.102316
# 2013-09-05          3.857294            0.858400           0.102316
# 2013-09-06          3.857294            0.858400           0.102316
# ...                      ...                 ...                ...
# 2023-12-27         26.852532            1.150467           0.320490
# 2023-12-28         26.597649            1.166617           0.312316
# 2023-12-29         26.310389            1.183850           0.302708
# 2023-12-30         25.979671            1.198083           0.291055
# 2023-12-31         25.681505            1.209333           0.279657
#
#                   pred  pred_adjust  diff
# date
# 2013-09-02 -142.724954          0.0   0.0
# 2013-09-03   -0.589476          0.0   0.0
# 2013-09-04   -0.311608          0.0   0.0
# 2013-09-05   -0.253391          0.0   0.0
# 2013-09-06   -0.215838          0.0   0.0
# ...                ...          ...   ...
# 2023-12-27         NaN          NaN   NaN
# 2023-12-28         NaN          NaN   NaN
# 2023-12-29         NaN          NaN   NaN
# 2023-12-30         NaN          NaN   NaN
# 2023-12-31         NaN          NaN   NaN
#
# [3772 rows x 22 columns]

# %%
def find_date_simple(df, count_col="count", detect_num=10):
      df = df.reset_index()
      for ind, row in df.iterrows():
            if df[count_col].max() <= detect_num:
                  print(f"No value available.")
                  break
            if row[count_col] >= detect_num:
                  date = row["date"]
                  return date

find_date_simple(df_2022)
# Out:
# Timestamp('2022-05-03 00:00:00')

# %%
for year in df["year"].unique().tolist():
      df_year = df[df["year"] == year]
      df_year = df_year.reset_index()
      print(f"-----------------Year {year}-------------------")
      print(f"Actual Start Date: {find_date_simple(df_year, 'count', 10)}")
      print(f"Predicted Start Date: {find_date_simple(df_year, 'pred_adjust', 10)}")
# Out:
# -----------------Year 2013-------------------
# No value available.
# Actual Start Date: None
# Predicted Start Date: 2013-10-01 00:00:00
# -----------------Year 2014-------------------
# Actual Start Date: 2014-05-02 00:00:00
# Predicted Start Date: 2014-05-03 00:00:00
# -----------------Year 2015-------------------
# Actual Start Date: 2015-05-12 00:00:00
# Predicted Start Date: 2015-05-13 00:00:00
# -----------------Year 2016-------------------
# Actual Start Date: 2016-04-26 00:00:00
# Predicted Start Date: 2016-04-27 00:00:00
# -----------------Year 2017-------------------
# Actual Start Date: 2017-06-19 00:00:00
# Predicted Start Date: 2017-06-20 00:00:00
# -----------------Year 2018-------------------
# Actual Start Date: 2018-05-14 00:00:00
# Predicted Start Date: 2018-05-15 00:00:00
# -----------------Year 2019-------------------
# Actual Start Date: 2019-01-21 00:00:00
# Predicted Start Date: 2019-02-22 00:00:00
# -----------------Year 2020-------------------
# Actual Start Date: 2020-01-09 00:00:00
# Predicted Start Date: 2020-02-17 00:00:00
# -----------------Year 2021-------------------
# Actual Start Date: 2021-04-29 00:00:00
# Predicted Start Date: 2021-04-30 00:00:00
# -----------------Year 2022-------------------
# Actual Start Date: 2022-05-03 00:00:00
# Predicted Start Date: 2022-05-04 00:00:00
# -----------------Year 2023-------------------
# Actual Start Date: 2023-05-03 00:00:00
# Predicted Start Date: None

# %%
test
# Out:
#             month  year       Temp     Flow   Level  count  october_Flow  \
# date
# 2023-04-01      4  2023   4.512500  11.5500  1.0580    0.0      0.996387
# 2023-04-02      4  2023   3.695833  10.5450  1.0335    0.0      0.996387
# 2023-04-03      4  2023   2.666667   9.4100  1.0065    0.0      0.996387
# 2023-04-04      4  2023   3.916667   8.5600  0.9835    0.0      0.996387
# 2023-04-05      4  2023   3.887500   7.7500  0.9620    0.0      0.996387
# ...           ...   ...        ...      ...     ...    ...           ...
# 2023-09-26      9  2023  13.229167   0.7195  0.5825    0.0      0.996387
# 2023-09-27      9  2023  12.479167   1.2015  0.6060    0.0      0.996387
# 2023-09-28      9  2023  12.450000   1.8365  0.6275    0.0      0.996387
# 2023-09-29      9  2023   9.529167   1.5055  0.6170    0.0      0.996387
# 2023-09-30      9  2023   9.541667   1.1315  0.6025    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2023-04-01       3.854583        1.01586      4.861828       3.270828
# 2023-04-02       3.854583        1.01586      4.861828       3.270828
# 2023-04-03       3.854583        1.01586      4.861828       3.270828
# 2023-04-04       3.854583        1.01586      4.861828       3.270828
# 2023-04-05       3.854583        1.01586      4.861828       3.270828
# ...                   ...            ...           ...            ...
# 2023-09-26       3.854583        1.01586      4.861828       3.270828
# 2023-09-27       3.854583        1.01586      4.861828       3.270828
# 2023-09-28       3.854583        1.01586      4.861828       3.270828
# 2023-09-29       3.854583        1.01586      4.861828       3.270828
# 2023-09-30       3.854583        1.01586      4.861828       3.270828
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2023-04-01       0.675435        0.829067           5.274028
# 2023-04-02       0.675435        0.829067           5.298056
# 2023-04-03       0.675435        0.829067           5.291667
# 2023-04-04       0.675435        0.829067           5.291111
# 2023-04-05       0.675435        0.829067           5.291111
# ...                   ...             ...                ...
# 2023-09-26       0.675435        0.829067          15.672917
# 2023-09-27       0.675435        0.829067          15.410278
# 2023-09-28       0.675435        0.829067          15.268889
# 2023-09-29       0.675435        0.829067          15.018194
# 2023-09-30       0.675435        0.829067          14.762778
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2023-04-01          1.853413           9.499333          3.111329
# 2023-04-02          1.827066           9.663333          3.028638
# 2023-04-03          1.836203           9.763167          2.966598
# 2023-04-04          1.836631           9.820000          2.925003
# 2023-04-05          1.836631           9.856667          2.890587
# ...                      ...                ...               ...
# 2023-09-26          2.119124           0.287667          0.109644
# 2023-09-27          2.003509           0.320650          0.198734
# 2023-09-28          2.058866           0.373283          0.340186
# 2023-09-29          2.280469           0.414950          0.397059
# 2023-09-30          2.449999           0.443317          0.417019
#
#             rolling_mean_Level  rolling_std_Level
# date
# 2023-04-01            0.996083           0.071829
# 2023-04-02            1.000733           0.069470
# 2023-04-03            1.003583           0.067820
# 2023-04-04            1.005100           0.066804
# 2023-04-05            1.006150           0.065831
# ...                        ...                ...
# 2023-09-26            0.542167           0.011124
# 2023-09-27            0.544383           0.016091
# 2023-09-28            0.547117           0.022122
# 2023-09-29            0.549533           0.025524
# 2023-09-30            0.551350           0.027290
#
# [183 rows x 19 columns]

# %%
forecast_steps = 183  # Adjust this according to how many steps ahead you want to forecast
forecast = results.forecast(steps=forecast_steps, exog=test[use_for_feats])
forecast_list = forecast.tolist()
forecast_list
# Out:
# /Users/jennylee/miniforge3/envs/563/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/jennylee/miniforge3/envs/563/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# [-98.72760886434651,
#  -94.7437531010977,
#  -93.2253372396566,
#  -92.69991827136698,
#  -92.98337615218486,
#  -94.87614741698951,
#  -100.56908593525804,
#  -102.75565638068622,
#  -112.72823221516751,
#  -107.94808992929893,
#  -107.56417158866122,
#  -108.30179410167977,
#  -106.79652694422009,
#  -105.90387611113113,
#  -105.78695225855597,
#  -106.17829905891904,
#  -105.54214208270548,
#  -104.5406285844225,
#  -102.66831130673143,
#  -101.53868816060913,
#  -101.32320580680164,
#  -100.97000451394047,
#  -101.49459542929367,
#  -100.26228286919218,
#  -99.70564614182365,
#  -102.74970332743624,
#  -105.00489321949442,
#  -109.59286675407759,
#  -119.66775188271356,
#  -127.49950408632117,
#  -129.75144808282096,
#  -132.75092393670627,
#  -139.85209156222516,
#  -144.06596301066963,
#  -142.7016340664012,
#  -142.0788947491816,
#  -141.52272097749562,
#  -142.10737060503948,
#  -139.46073572473279,
#  -135.74747717495256,
#  -137.4145881528193,
#  -139.2699532479396,
#  -143.84542196082305,
#  -149.23503783089984,
#  -156.9743856708992,
#  -161.65302938946445,
#  -162.1177834827986,
#  -162.7032804155216,
#  -162.286345557937,
#  -159.58260472824963,
#  -155.35304569728714,
#  -150.96215603816802,
#  -148.31043607443212,
#  -144.3913002370274,
#  -141.0757818739471,
#  -140.1404080011788,
#  -138.3296565753467,
#  -136.25594766979486,
#  -134.73302321070162,
#  -133.13046149557135,
#  -131.33854235329147,
#  -129.84640343967453,
#  -127.21958367279285,
#  -125.23705248152578,
#  -122.91352697823379,
#  -119.97138661706003,
#  -117.07445532967847,
#  -115.42631781257023,
#  -115.1068801447035,
#  -112.81696496494317,
#  -112.45129674172495,
#  -111.83383132497966,
#  -111.78692879391895,
#  -108.93132112363799,
#  -102.8843719975747,
#  -98.42950286569135,
#  -95.68071905773377,
#  -91.82939563190962,
#  -89.27477850735215,
#  -88.12632948553642,
#  -86.8955124270044,
#  -86.11546340635971,
#  -84.41042108742022,
#  -85.4159811997115,
#  -85.55857161543315,
#  -83.30875513218496,
#  -83.2982110124218,
#  -84.27374696130971,
#  -85.17657288439182,
#  -86.64347979948207,
#  -87.39730300421957,
#  -86.74251972274578,
#  -85.95109588074024,
#  -85.42048556664497,
#  -87.65567515541034,
#  -90.79585431306305,
#  -93.91042172612094,
#  -94.27713873689515,
#  -92.16603120206742,
#  -91.34684498898889,
#  -89.64777573582296,
#  -88.93567435282955,
#  -87.45906974909155,
#  -86.82487326573869,
#  -87.16015617799576,
#  -88.21419588969877,
#  -90.26429894302953,
#  -90.55478815082631,
#  -87.2186638192195,
#  -80.80632430782441,
#  -78.68440749148988,
#  -75.77559517242378,
#  -74.18949951367802,
#  -73.513094358437,
#  -73.05205742266355,
#  -75.11727310769777,
#  -76.18207084481264,
#  -76.38087983930404,
#  -76.36955414548947,
#  -76.17377134512026,
#  -75.9119844493548,
#  -75.73954268153307,
#  -75.11568834832997,
#  -74.60254221416653,
#  -73.42720232761485,
#  -71.88020684571791,
#  -70.36484127544759,
#  -69.70121103024542,
#  -69.82181943279852,
#  -69.9231289901486,
#  -69.68422543759027,
#  -69.42584435200877,
#  -69.27471922275004,
#  -69.46335590830415,
#  -70.57125771150038,
#  -73.60552713997538,
#  -77.34044908473413,
#  -80.66059194780041,
#  -82.48478266327129,
#  -81.47346170720948,
#  -79.53006988711013,
#  -77.67604752159741,
#  -77.43629475302782,
#  -77.47791545173504,
#  -78.33286236566369,
#  -78.05604068263574,
#  -77.68073426119327,
#  -77.57420731059688,
#  -78.54464737718922,
#  -78.77073160454256,
#  -79.34924602523756,
#  -79.67753958389642,
#  -79.90468735247896,
#  -80.00166162890673,
#  -79.99208369315409,
#  -79.04761451190222,
#  -79.70497071471686,
#  -79.92500964368026,
#  -79.97138684529511,
#  -79.10096008663004,
#  -79.00949883995997,
#  -78.5225308427191,
#  -78.07066150771175,
#  -77.25576853154553,
#  -74.82159428908278,
#  -68.91819954549146,
#  -59.99057157131108,
#  -50.84080119356747,
#  -42.694703023656416,
#  -40.39971776073526,
#  -40.5385820714738,
#  -41.735698060416894,
#  -42.9681713971263,
#  -44.29221049192802,
#  -45.29541551722548,
#  -45.467983052715454,
#  -46.79536064728234,
#  -44.96474997854148,
#  -38.3552051647132,
#  -33.66669820861341,
#  -33.054599109538,
#  -35.12373504007314,
#  -36.4076974951073]

# %%
test["pred"] = forecast_list
test
# Out:
# /var/folders/c5/pphx1c0n3lb12sy85_ybqxqm0000gn/T/ipykernel_6694/3597401935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["pred"] = forecast_list
#             month  year       Temp     Flow   Level  count  october_Flow  \
# date
# 2023-04-01      4  2023   4.512500  11.5500  1.0580    0.0      0.996387
# 2023-04-02      4  2023   3.695833  10.5450  1.0335    0.0      0.996387
# 2023-04-03      4  2023   2.666667   9.4100  1.0065    0.0      0.996387
# 2023-04-04      4  2023   3.916667   8.5600  0.9835    0.0      0.996387
# 2023-04-05      4  2023   3.887500   7.7500  0.9620    0.0      0.996387
# ...           ...   ...        ...      ...     ...    ...           ...
# 2023-09-26      9  2023  13.229167   0.7195  0.5825    0.0      0.996387
# 2023-09-27      9  2023  12.479167   1.2015  0.6060    0.0      0.996387
# 2023-09-28      9  2023  12.450000   1.8365  0.6275    0.0      0.996387
# 2023-09-29      9  2023   9.529167   1.5055  0.6170    0.0      0.996387
# 2023-09-30      9  2023   9.541667   1.1315  0.6025    0.0      0.996387
#
#             november_Flow  december_Temp  january_Temp  feburary_Temp  \
# date
# 2023-04-01       3.854583        1.01586      4.861828       3.270828
# 2023-04-02       3.854583        1.01586      4.861828       3.270828
# 2023-04-03       3.854583        1.01586      4.861828       3.270828
# 2023-04-04       3.854583        1.01586      4.861828       3.270828
# 2023-04-05       3.854583        1.01586      4.861828       3.270828
# ...                   ...            ...           ...            ...
# 2023-09-26       3.854583        1.01586      4.861828       3.270828
# 2023-09-27       3.854583        1.01586      4.861828       3.270828
# 2023-09-28       3.854583        1.01586      4.861828       3.270828
# 2023-09-29       3.854583        1.01586      4.861828       3.270828
# 2023-09-30       3.854583        1.01586      4.861828       3.270828
#
#             october_Level  november_Level  rolling_mean_Temp  \
# date
# 2023-04-01       0.675435        0.829067           5.274028
# 2023-04-02       0.675435        0.829067           5.298056
# 2023-04-03       0.675435        0.829067           5.291667
# 2023-04-04       0.675435        0.829067           5.291111
# 2023-04-05       0.675435        0.829067           5.291111
# ...                   ...             ...                ...
# 2023-09-26       0.675435        0.829067          15.672917
# 2023-09-27       0.675435        0.829067          15.410278
# 2023-09-28       0.675435        0.829067          15.268889
# 2023-09-29       0.675435        0.829067          15.018194
# 2023-09-30       0.675435        0.829067          14.762778
#
#             rolling_std_Temp  rolling_mean_Flow  rolling_std_Flow  \
# date
# 2023-04-01          1.853413           9.499333          3.111329
# 2023-04-02          1.827066           9.663333          3.028638
# 2023-04-03          1.836203           9.763167          2.966598
# 2023-04-04          1.836631           9.820000          2.925003
# 2023-04-05          1.836631           9.856667          2.890587
# ...                      ...                ...               ...
# 2023-09-26          2.119124           0.287667          0.109644
# 2023-09-27          2.003509           0.320650          0.198734
# 2023-09-28          2.058866           0.373283          0.340186
# 2023-09-29          2.280469           0.414950          0.397059
# 2023-09-30          2.449999           0.443317          0.417019
#
#             rolling_mean_Level  rolling_std_Level        pred
# date
# 2023-04-01            0.996083           0.071829 -118.715111
# 2023-04-02            1.000733           0.069470 -114.025015
# 2023-04-03            1.003583           0.067820 -112.645155
# 2023-04-04            1.005100           0.066804 -112.115355
# 2023-04-05            1.006150           0.065831 -112.286329
# ...                        ...                ...         ...
# 2023-09-26            0.542167           0.011124  -54.007162
# 2023-09-27            0.544383           0.016091  -49.356440
# 2023-09-28            0.547117           0.022122  -48.881566
# 2023-09-29            0.549533           0.025524  -51.152505
# 2023-09-30            0.551350           0.027290  -52.586561
#
# [183 rows x 20 columns]

# %%
def find_peak_dates(df, column):
      df = df.reset_index()
      year_record = {}

      for year in df["year"].unique().tolist():
            df_year = df[df["year"] == year]
            max_num_ind = df_year[column].idxmax()
            year_record[str(df.loc[max_num_ind, "date"])] = df.loc[max_num_ind, column]
      return year_record

find_peak_dates(df, "count")
# Out:
# {'2013-09-02 00:00:00': 0.0,
#  '2014-06-16 00:00:00': 881.0,
#  '2015-06-16 00:00:00': 713.0,
#  '2016-06-01 00:00:00': 1672.0,
#  '2017-06-22 00:00:00': 1119.0,
#  '2018-06-07 00:00:00': 756.0,
#  '2019-05-10 00:00:00': 975.0,
#  '2020-06-10 00:00:00': 756.0,
#  '2021-05-20 00:00:00': 1247.0,
#  '2022-06-05 00:00:00': 560.0,
#  '2023-05-30 00:00:00': 976.0}

# %%
year_dict = find_peak_dates(df, "pred_adjust")
year_dict
# Out:
# /var/folders/c5/pphx1c0n3lb12sy85_ybqxqm0000gn/T/ipykernel_6694/1134270277.py:7: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   max_num_ind = df_year[column].idxmax()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[481], line 1
# ----> 1 year_dict = find_peak_dates(df, "pred_adjust")
#       2 year_dict
#
# Cell In[480], line 8, in find_peak_dates(df, column)
#       6       df_year = df[df["year"] == year]
#       7       max_num_ind = df_year[column].idxmax()
# ----> 8       year_record[str(df.loc[max_num_ind, "date"])] = df.loc[max_num_ind, column]
#       9 return year_record
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/pandas/core/frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
# -> 4221     row = self.index.get_loc(index)
#    4222     return series._values[row]
#    4224 # For MultiIndex going through engine effectively restricts us to
#    4225 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~/miniforge3/envs/563/lib/python3.11/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: nan

# %%
df.dropna(subset=["pred_adjust"])
# Out:
#             month  year       Temp        Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273    0.875500  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833    0.790500  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500    0.749000  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500    0.694500  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167    0.668000  0.5280    0.0      7.679129
# ...           ...   ...        ...         ...     ...    ...           ...
# 2022-12-27     12  2022   6.337500  174.500000  2.7365    0.0     23.103871
# 2022-12-28     12  2022   6.458333   86.250000  2.0680    0.0     23.103871
# 2022-12-29     12  2022   4.145833   43.699999  1.6175    0.0     23.103871
# 2022-12-30     12  2022   6.041667   57.050001  1.7540    0.0     23.103871
# 2022-12-31     12  2022   6.545833   65.949999  1.8775    0.0     23.103871
#
#             november_Flow  december_Temp  january_Temp  ...  november_Level  \
# date                                                    ...
# 2013-09-02        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-03        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-04        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-05        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-06        28.3825       3.965188      4.324905  ...        1.166450
# ...                   ...            ...           ...  ...             ...
# 2022-12-27        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-28        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-29        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-30        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-31        66.4550       1.127608      2.843952  ...        1.681733
#
#             rolling_mean_Temp  rolling_std_Temp  rolling_mean_Flow  \
# date
# 2013-09-02           9.514444          2.539781           8.101333
# 2013-09-03           9.514444          2.539781           8.101333
# 2013-09-04           9.514444          2.539781           8.101333
# 2013-09-05           9.514444          2.539781           8.101333
# 2013-09-06           9.514444          2.539781           8.101333
# ...                       ...               ...                ...
# 2022-12-27           0.357083          3.486503          22.497167
# 2022-12-28           0.527361          3.657231          25.116500
# 2022-12-29           0.710694          3.697295          26.367167
# 2022-12-30           0.831528          3.812414          28.072833
# 2022-12-31           1.083333          3.934229          30.102167
#
#             rolling_std_Flow  rolling_mean_Level  rolling_std_Level  \
# date
# 2013-09-02          3.857294            0.858400           0.102316
# 2013-09-03          3.857294            0.858400           0.102316
# 2013-09-04          3.857294            0.858400           0.102316
# 2013-09-05          3.857294            0.858400           0.102316
# 2013-09-06          3.857294            0.858400           0.102316
# ...                      ...                 ...                ...
# 2022-12-27         46.604569            1.077833           0.512663
# 2022-12-28         47.931827            1.114250           0.543046
# 2022-12-29         47.910179            1.137600           0.549296
# 2022-12-30         48.066264            1.165967           0.558657
# 2022-12-31         48.345955            1.199733           0.570300
#
#                   pred  pred_adjust      diff
# date
# 2013-09-02 -142.724954     0.000000  0.000000
# 2013-09-03   -0.589476     0.000000  0.000000
# 2013-09-04   -0.311608     0.000000  0.000000
# 2013-09-05   -0.253391     0.000000  0.000000
# 2013-09-06   -0.215838     0.000000  0.000000
# ...                ...          ...       ...
# 2022-12-27    1.551895     1.551895  1.551895
# 2022-12-28   -0.710342     0.000000  0.000000
# 2022-12-29   -1.820656     0.000000  0.000000
# 2022-12-30   -2.652565     0.000000  0.000000
# 2022-12-31   -3.634622     0.000000  0.000000
#
# [3407 rows x 22 columns]

# %%
df_no_2022 = df[df["year"] <= 2022]
df_no_2022
# Out:
#             month  year       Temp        Flow   Level  count  october_Flow  \
# date
# 2013-09-02      9  2013  19.127273    0.875500  0.5480    0.0      7.679129
# 2013-09-03      9  2013  18.045833    0.790500  0.5405    0.0      7.679129
# 2013-09-04      9  2013  17.062500    0.749000  0.5365    0.0      7.679129
# 2013-09-05      9  2013  16.837500    0.694500  0.5300    0.0      7.679129
# 2013-09-06      9  2013  16.954167    0.668000  0.5280    0.0      7.679129
# ...           ...   ...        ...         ...     ...    ...           ...
# 2022-12-27     12  2022   6.337500  174.500000  2.7365    0.0     23.103871
# 2022-12-28     12  2022   6.458333   86.250000  2.0680    0.0     23.103871
# 2022-12-29     12  2022   4.145833   43.699999  1.6175    0.0     23.103871
# 2022-12-30     12  2022   6.041667   57.050001  1.7540    0.0     23.103871
# 2022-12-31     12  2022   6.545833   65.949999  1.8775    0.0     23.103871
#
#             november_Flow  december_Temp  january_Temp  ...  november_Level  \
# date                                                    ...
# 2013-09-02        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-03        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-04        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-05        28.3825       3.965188      4.324905  ...        1.166450
# 2013-09-06        28.3825       3.965188      4.324905  ...        1.166450
# ...                   ...            ...           ...  ...             ...
# 2022-12-27        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-28        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-29        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-30        66.4550       1.127608      2.843952  ...        1.681733
# 2022-12-31        66.4550       1.127608      2.843952  ...        1.681733
#
#             rolling_mean_Temp  rolling_std_Temp  rolling_mean_Flow  \
# date
# 2013-09-02           9.514444          2.539781           8.101333
# 2013-09-03           9.514444          2.539781           8.101333
# 2013-09-04           9.514444          2.539781           8.101333
# 2013-09-05           9.514444          2.539781           8.101333
# 2013-09-06           9.514444          2.539781           8.101333
# ...                       ...               ...                ...
# 2022-12-27           0.357083          3.486503          22.497167
# 2022-12-28           0.527361          3.657231          25.116500
# 2022-12-29           0.710694          3.697295          26.367167
# 2022-12-30           0.831528          3.812414          28.072833
# 2022-12-31           1.083333          3.934229          30.102167
#
#             rolling_std_Flow  rolling_mean_Level  rolling_std_Level  \
# date
# 2013-09-02          3.857294            0.858400           0.102316
# 2013-09-03          3.857294            0.858400           0.102316
# 2013-09-04          3.857294            0.858400           0.102316
# 2013-09-05          3.857294            0.858400           0.102316
# 2013-09-06          3.857294            0.858400           0.102316
# ...                      ...                 ...                ...
# 2022-12-27         46.604569            1.077833           0.512663
# 2022-12-28         47.931827            1.114250           0.543046
# 2022-12-29         47.910179            1.137600           0.549296
# 2022-12-30         48.066264            1.165967           0.558657
# 2022-12-31         48.345955            1.199733           0.570300
#
#                   pred  pred_adjust      diff
# date
# 2013-09-02 -142.724954     0.000000  0.000000
# 2013-09-03   -0.589476     0.000000  0.000000
# 2013-09-04   -0.311608     0.000000  0.000000
# 2013-09-05   -0.253391     0.000000  0.000000
# 2013-09-06   -0.215838     0.000000  0.000000
# ...                ...          ...       ...
# 2022-12-27    1.551895     1.551895  1.551895
# 2022-12-28   -0.710342     0.000000  0.000000
# 2022-12-29   -1.820656     0.000000  0.000000
# 2022-12-30   -2.652565     0.000000  0.000000
# 2022-12-31   -3.634622     0.000000  0.000000
#
# [3407 rows x 22 columns]

# %%
actual_peak = find_peak_dates(df_no_2022, "count")
pred_peak = find_peak_dates(df_no_2022, "pred_adjust")

# %%
actual_peak = pd.DataFrame(actual_peak, index=[0]).T
pred_peak = pd.DataFrame(pred_peak, index=[0]).T

# %%
display(pred_peak)
# Out:
#                               0
# 2013-10-01 00:00:00   12.281468
# 2014-06-17 00:00:00  444.932550
# 2015-06-17 00:00:00  435.784225
# 2016-06-02 00:00:00  857.726580
# 2017-06-23 00:00:00  648.722881
# 2018-06-08 00:00:00  423.884286
# 2019-05-11 00:00:00  508.202240
# 2020-06-11 00:00:00  354.944758
# 2021-05-20 00:00:00  807.483809
# 2022-06-11 00:00:00  352.452681

# %%
adjust_val = lambda row: 0 if row["pred"] <= 0 else row["pred"]
test["pred_adjust"] = test.apply(adjust_val, axis=1)

plt.figure(figsize=(12, 6))
plt.plot(test.index, test['count'], label='Actual Count', color='blue')
plt.plot(test.index, test['pred_adjust'], label='Prediction', color='red')

# Adding title and labels
plt.title('Prediction and Adjusted Prediction Over Time')
plt.xlabel('Date')
plt.ylabel('Values')

# Adding legend
plt.legend()

# Display the plot
plt.show()
# Out:
# /var/folders/c5/pphx1c0n3lb12sy85_ybqxqm0000gn/T/ipykernel_6694/2561461406.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["pred_adjust"] = test.apply(adjust_val, axis=1)

# %%
pred_date = find_date(df_2023, "pred_adjust", 3, 5)
pred_date
# Out:
#  Ind: 1, Count: 0.0
#  Ind: 2, Count: 0.0
#  Ind: 3, Count: 0.0
#  Ind: 4, Count: 0.0
#  Ind: 5, Count: 0.0
#  Ind: 6, Count: 0.0
#  Ind: 7, Count: 0.0
#  Ind: 8, Count: 0.0
#  Ind: 9, Count: 0.0
#  Ind: 10, Count: 0.0
#  Ind: 11, Count: 0.0
#  Ind: 12, Count: 0.0
#  Ind: 13, Count: 0.0
#  Ind: 14, Count: 0.0
#  Ind: 15, Count: 0.0
#  Ind: 16, Count: 0.0
#  Ind: 17, Count: 0.0
#  Ind: 18, Count: 0.0
#  Ind: 19, Count: 0.0
#  Ind: 20, Count: 0.0
#  Ind: 21, Count: 0.0
#  Ind: 22, Count: 0.0
#  Ind: 23, Count: 0.0
#  Ind: 24, Count: 0.0
#  Ind: 25, Count: 0.0
#  Ind: 26, Count: 0.0
#  Ind: 27, Count: 0.0
#  Ind: 28, Count: 0.0
#  Ind: 29, Count: 0.0
#  Ind: 30, Count: 0.0
#  Ind: 31, Count: 0.0
#  Ind: 32, Count: 0.0
#  Ind: 33, Count: 0.0
#  Ind: 34, Count: 0.0
#  Ind: 35, Count: 0.0
#  Ind: 36, Count: 0.0
#  Ind: 37, Count: 0.0
#  Ind: 38, Count: 0.0
#  Ind: 39, Count: 0.0
#  Ind: 40, Count: 0.0
#  Ind: 41, Count: 0.0
#  Ind: 42, Count: 0.0
#  Ind: 43, Count: 0.0
#  Ind: 44, Count: 0.0
#  Ind: 45, Count: 0.0
#  Ind: 46, Count: 0.0
#  Ind: 47, Count: 0.0
#  Ind: 48, Count: 0.0
#  Ind: 49, Count: 0.0
#  Ind: 50, Count: 0.0
#  Ind: 51, Count: 0.0
#  Ind: 52, Count: 0.0
#  Ind: 53, Count: 0.0
#  Ind: 54, Count: 0.0
#  Ind: 55, Count: 0.0
#  Ind: 56, Count: 0.0
#  Ind: 57, Count: 0.0
#  Ind: 58, Count: 0.0
#  Ind: 59, Count: 0.0
#  Ind: 60, Count: 0.0
#  Ind: 61, Count: 0.0
#  Ind: 62, Count: 0.0
#  Ind: 63, Count: 0.0
#  Ind: 64, Count: 0.0
#  Ind: 65, Count: 0.0
#  Ind: 66, Count: 0.0
#  Ind: 67, Count: 0.0
#  Ind: 68, Count: 0.0
#  Ind: 69, Count: 0.0
#  Ind: 70, Count: 0.0
#  Ind: 71, Count: 0.0
#  Ind: 72, Count: 0.0
#  Ind: 73, Count: 0.0
#  Ind: 74, Count: 0.0
#  Ind: 75, Count: 0.0
#  Ind: 76, Count: 0.0
#  Ind: 77, Count: 0.0
#  Ind: 78, Count: 0.0
#  Ind: 79, Count: 0.0
#  Ind: 80, Count: 0.0
#  Ind: 81, Count: 0.0
#  Ind: 82, Count: 0.0
#  Ind: 83, Count: 0.0
#  Ind: 84, Count: 0.0
#  Ind: 85, Count: 0.0
#  Ind: 86, Count: 0.0
#  Ind: 87, Count: 0.0
#  Ind: 88, Count: 0.0
#  Ind: 89, Count: 0.0
#  Ind: 90, Count: 0.0
#  Ind: 91, Count: 0.0
#  Ind: 92, Count: 0.0
#  Ind: 93, Count: 0.0
#  Ind: 94, Count: 0.0
#  Ind: 95, Count: 0.0
#  Ind: 96, Count: 0.0
#  Ind: 97, Count: 0.0
#  Ind: 98, Count: 0.0
#  Ind: 99, Count: 0.0
#  Ind: 100, Count: 0.0
#  Ind: 101, Count: 0.0
#  Ind: 102, Count: 0.0
#  Ind: 103, Count: 0.0
#  Ind: 104, Count: 0.0
#  Ind: 105, Count: 0.0
#  Ind: 106, Count: 0.0
#  Ind: 107, Count: 0.0
#  Ind: 108, Count: 0.0
#  Ind: 109, Count: 0.0
#  Ind: 110, Count: 0.0
#  Ind: 111, Count: 0.0
#  Ind: 112, Count: 0.0
#  Ind: 113, Count: 0.0
#  Ind: 114, Count: 0.0
#  Ind: 115, Count: 0.0
#  Ind: 116, Count: 0.0
#  Ind: 117, Count: 0.0
#  Ind: 118, Count: 0.0
#  Ind: 119, Count: 0.0
#  Ind: 120, Count: 0.0
#  Ind: 121, Count: 0.0
#  Ind: 122, Count: 20.0
#  Ind: 123, Count: 0.0
#  Ind: 124, Count: 43.0
#  Ind: 125, Count: 0.0
#  Ind: 126, Count: 0.0
#  Ind: 127, Count: 104.0
#  Ind: 128, Count: 0.0
#  Ind: 129, Count: 161.0
#  Ind: 130, Count: 0.0
#  Ind: 131, Count: 197.0
#  Ind: 132, Count: 0.0
#  Ind: 133, Count: 0.0
#  Ind: 134, Count: 162.0
# Timestamp('2023-05-15 00:00:00')
